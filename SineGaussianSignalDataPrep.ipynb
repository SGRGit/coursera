# %% [markdown]
# <a href="https://colab.research.google.com/github/SGRGit/coursera/blob/master/SineGaussianSignalDataPrep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(-1, 1, 2 * 100, endpoint=False)
i, q, e = signal.gausspulse(t, fc=5, retquad=True, retenv=True)
plt.plot(t, i, t, q, t, e, '--')
# Out:
# [<matplotlib.lines.Line2D at 0x7f899912b978>,
#  <matplotlib.lines.Line2D at 0x7f899912bba8>,
#  <matplotlib.lines.Line2D at 0x7f899912bef0>]

# %%
t = np.linspace(-5, 5, 2 * 100, endpoint=False)
i, q, e = signal.gausspulse(t, fc=2, retquad=True, retenv=True)
n = 0.05*np.random.randn(len(t)) 
xn = i + n
plt.plot(t, xn, 'b', t, i, 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7f89946fe5f8>,
#  <matplotlib.lines.Line2D at 0x7f89946fe748>]

# %%
from scipy.fftpack import fft
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
fs = 2

"""alpha = np.linspace(0.1, 10, num = 500)
a = 50 #Amplitude

fs = 1e3
fr = np.float(100.0) #Signal Ffrequency
N = 1e3
t_value = np.arange(N) / fs"""

t = np.linspace(-5, 5, 2 * 100, endpoint=False)

"""def get_fft_values(y_values):   
  s = len(y_values) 
  k = np.arange(s)
  T = s/fs
  frq = k/T # two sides frequency range
  f_values = frq[range(int(s/2))] # one side frequency range
  fft_values = np.fft.fft(y_values)/n # fft computing and normalization
  fft_values = fft_values[range(int(s/2))]
  return f_values, fft_values
  
def plot_fft(signal, raw):
  freq_s,  fft_s = get_fft_values(signal)
  freq_raw, fft_raw = get_fft_values(raw)
  ft, (axft1, axft2) = plt.subplots(2, 1)
  ft.set_figwidth(30)
  ft.set_figheight(10)
  axft1.plot(freq_raw, abs(fft_raw), 'g' , alpha=0.75)
  axft2.plot(freq_s, abs(fft_s), 'r', alpha=0.75)
  #axft1.title.set_text('Plot for Iteration %d' %i)
  
from scipy.signal import welch
 
def get_psd_values(y_values, fs):
    f_values, psd_values = welch(y_values, fs=fs)
    return f_values, psd_values

def plot_psd(signal, fs):
  f_values, psd_values = get_psd_values(xn, fs)
  ft, (axft1) = plt.subplots(1, 1)
  ft.set_figwidth(10)
  ft.set_figheight(5)
  axft1.plot(f_values, psd_values, 'g' , alpha=0.75)
  axft1.title.set_text('PSD for Iteration %d' %i)"""


def plot_spectrogram_sig(signal, fs):
  from scipy import signal
  f, t, Sxx = signal.spectrogram(signal, fs)
  plt.pcolormesh(t, f[0:500], Sxx[0:500])
  plt.ylabel('Frequency [Hz]')
  plt.xlabel('Time [sec]')
  #plt.title('Spectrogram for Actual Data : Iteration %d' %i)
  #plt.savefig(os.path.join(seta_train_dir,'SPG for Signal%d'%i))
  #plt.close()
  
#for i in range(0, 4, 1):  
  #Set 1
  #x = (a*np.sin(2*np.pi*alpha[i]*fr*t_value))
  #n = 1e2*np.random.randn(len(t_value)) #Noise
  
  i, q, e = signal.gausspulse(t, fc=2, retquad=True, retenv=True)
  #plt.plot(t, i+n, 'b', t, i, 'r')

  n = 0.05*np.random.randn(len(t)) 
  xn = i + n # Noise+Signal

  #plot_source(x, n, xn, t_value, i)
#plot_fft(i, xn)
  #plot_psd(xn, fs)
plot_spectrogram_sig(xn, fs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-425c1e7038ad> in <module>()
#      74 #plot_fft(i, xn)
#      75   #plot_psd(xn, fs)
# ---> 76 plot_spectrogram_sig(xn, fs)
#      77   #plot_spectrogram(xn2, fs)
#
# <ipython-input-67-425c1e7038ad> in plot_spectrogram_sig(signal, fs)
#      52 def plot_spectrogram_sig(signal, fs):
#      53   from scipy import signal
# ---> 54   f, t, Sxx = signal.spectrogram(signal, fs)
#      55   plt.pcolormesh(t, f[0:500], Sxx[0:500])
#      56   plt.ylabel('Frequency [Hz]')
#
# /usr/local/lib/python3.6/dist-packages/scipy/signal/spectral.py in spectrogram(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode)
#     738     # need to set default for nperseg before setting default for noverlap below
#     739     window, nperseg = _triage_segments(window, nperseg,
# --> 740                                        input_length=x.shape[axis])
#     741
#     742     # Less overlap than welch, so samples are more statisically independent
#
# AttributeError: module 'scipy.signal' has no attribute 'shape'

# %%
from scipy import signal
t = np.linspace(-5, 5, 2 * 100, endpoint=False)
i, q, e = signal.gausspulse(t, fc=2, retquad=True, retenv=True)
n = 0.05*np.random.randn(len(t)) 
xn = i + n
plt.plot(t, xn, 'b', t, i, 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7f8994313b00>,
#  <matplotlib.lines.Line2D at 0x7f8994313c88>]

# %%
from scipy import signal
freqs, times, spectrogram = signal.spectrogram(xn)

plt.figure(figsize=(5, 4))
plt.imshow(spectrogram, aspect='auto')
plt.title('Spectrogram')
plt.ylabel('Frequency band')
plt.xlabel('Time window')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/signal/spectral.py:1969: UserWarning: nperseg = 256 is greater than input length  = 200, using nperseg = 200
#   .format(nperseg, input_length))
